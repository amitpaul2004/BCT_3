# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
phonepe = pd.read_excel(r"D:\testing\BCT_3\data\phonepe_transactions_dataset.xlsx")
paypal = pd.read_excel(r"D:\testing\BCT_3\data\paypal_transactions_dataset.xlsx")
razorpay = pd.read_excel(r"D:\testing\BCT_3\data\razer_dataset_2026.xlsx")

# %%
phonepe.head()
# Out:
#   Transaction_ID User_ID       City        State  Amount_INR Payment_Type  \
# 0       TXN00001    U400  Hyderabad    Telangana         841         Card
# 1       TXN00002    U391      Delhi        Delhi        2268         Card
# 2       TXN00003    U300    Kolkata  West Bengal        4710       Wallet
# 3       TXN00004    U579  Hyderabad    Telangana        4822       Wallet
# 4       TXN00005    U614      Delhi        Delhi        2216          UPI
#
#   Merchant_Category   Status        Date
# 0            Travel  Success  2024-10-08
# 1              Food  Success  2025-07-11
# 2           Grocery   Failed  2024-06-24
# 3           Grocery  Success  2025-11-01
# 4            Travel   Failed  2024-12-28

# %%
paypal.head()
# Out:
#   Transaction_ID      User_Email    Country  Amount_USD Payment_Type  \
# 0        PP00001  user1@mail.com      India       13.95         Card
# 1        PP00002  user2@mail.com        USA      416.08         Bank
# 2        PP00003  user3@mail.com  Australia       44.61      Balance
# 3        PP00004  user4@mail.com     France      462.78         Card
# 4        PP00005  user5@mail.com  Australia      457.48         Bank
#
#    Merchant_Type     Status        Date
# 0  Digital Goods  Completed  2026-02-08
# 1   Subscription  Completed  2026-02-26
# 2       Services  Completed  2025-11-30
# 3       Services  Completed  2024-11-14
# 4   Subscription  Completed  2024-01-15

# %%
razorpay.head()
# Out:
#   Product_ID         Product_Name  Category  Price_USD  RGB    Connectivity  \
# 0      RZ001  Razer DeathAdder V3     Mouse        149  Yes           Wired
# 1      RZ002    Razer Basilisk V3     Mouse        169  Yes  Wired/Wireless
# 2      RZ003  Razer BlackWidow V4  Keyboard        229  Yes           Wired
# 3      RZ004  Razer Huntsman Mini  Keyboard        119  Yes           Wired
# 4      RZ005      Razer Kraken V3   Headset        129  Yes           Wired
#
#    Rating  Release_Year
# 0     4.8          2023
# 1     4.7          2022
# 2     4.6          2023
# 3     4.5          2021
# 4     4.4          2022

# %%
print(phonepe.columns)
print(paypal.columns)
print(razorpay.columns)
# Out:
# Index(['Transaction_ID', 'User_ID', 'City', 'State', 'Amount_INR',
#        'Payment_Type', 'Merchant_Category', 'Status', 'Date'],
#       dtype='object')
# Index(['Transaction_ID', 'User_Email', 'Country', 'Amount_USD', 'Payment_Type',
#        'Merchant_Type', 'Status', 'Date'],
#       dtype='object')
# Index(['Product_ID', 'Product_Name', 'Category', 'Price_USD', 'RGB',
#        'Connectivity', 'Rating', 'Release_Year'],
#       dtype='object')

# %%
phonepe.columns = phonepe.columns.str.strip()
paypal.columns = paypal.columns.str.strip()
razorpay.columns = razorpay.columns.str.strip()

# %%
phonepe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Transaction_ID     500 non-null    object
#  1   User_ID            500 non-null    object
#  2   City               500 non-null    object
#  3   State              500 non-null    object
#  4   Amount_INR         500 non-null    int64
#  5   Payment_Type       500 non-null    object
#  6   Merchant_Category  500 non-null    object
#  7   Status             500 non-null    object
#  8   Date               500 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 35.3+ KB

# %%
paypal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  500 non-null    object
#  1   User_Email      500 non-null    object
#  2   Country         500 non-null    object
#  3   Amount_USD      500 non-null    float64
#  4   Payment_Type    500 non-null    object
#  5   Merchant_Type   500 non-null    object
#  6   Status          500 non-null    object
#  7   Date            500 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 31.4+ KB

# %%
razorpay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    12 non-null     object
#  1   Product_Name  12 non-null     object
#  2   Category      12 non-null     object
#  3   Price_USD     12 non-null     int64
#  4   RGB           12 non-null     object
#  5   Connectivity  11 non-null     object
#  6   Rating        12 non-null     float64
#  7   Release_Year  12 non-null     int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 900.0+ bytes

# %%
phonepe.describe()
# Out:
#         Amount_INR
# count   500.000000
# mean   2524.746000
# std    1463.478185
# min      26.000000
# 25%    1253.500000
# 50%    2534.500000
# 75%    3786.250000
# max    4995.000000

# %%
paypal.describe()
# Out:
#        Amount_USD
# count  500.000000
# mean   261.369700
# std    141.615514
# min      5.640000
# 25%    145.115000
# 50%    269.720000
# 75%    383.552500
# max    499.570000

# %%
razorpay.describe()
# Out:
#          Price_USD     Rating  Release_Year
# count    12.000000  12.000000     12.000000
# mean    873.166667   4.583333   2022.916667
# std    1341.033918   0.164225      1.505042
# min      29.000000   4.300000   2021.000000
# 25%     126.500000   4.475000   2022.000000
# 50%     164.000000   4.600000   2023.000000
# 75%     796.500000   4.700000   2023.250000
# max    3499.000000   4.800000   2026.000000

# %%
phonepe.isnull().sum()
# Out:
# Transaction_ID       0
# User_ID              0
# City                 0
# State                0
# Amount_INR           0
# Payment_Type         0
# Merchant_Category    0
# Status               0
# Date                 0
# dtype: int64

# %%
paypal.isnull().sum()
# Out:
# Transaction_ID    0
# User_Email        0
# Country           0
# Amount_USD        0
# Payment_Type      0
# Merchant_Type     0
# Status            0
# Date              0
# dtype: int64

# %%
razorpay.isnull().sum()
# Out:
# Product_ID      0
# Product_Name    0
# Category        0
# Price_USD       0
# RGB             0
# Connectivity    1
# Rating          0
# Release_Year    0
# dtype: int64

# %%
print(razorpay.columns)
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Price_USD', 'RGB',
#        'Connectivity', 'Rating', 'Release_Year'],
#       dtype='object')

# %%
phonepe["Status"].value_counts().plot(kind="bar", title="PhonePe Transactions")
plt.show()

# %%
paypal["Status"].value_counts().plot(kind="bar", title="PayPal Transactions")
plt.show()

# %%
print(razorpay.columns)
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Price_USD', 'RGB',
#        'Connectivity', 'Rating', 'Release_Year'],
#       dtype='object')

# %%
print("PhonePe rows:", len(phonepe))
print("PayPal rows:", len(paypal))
print("Razorpay rows:", len(razorpay))
# Out:
# PhonePe rows: 500
# PayPal rows: 500
# Razorpay rows: 12
