# %%
# Enter Name
userId = input("Enter Your Name Here -> ")
print("Welcome to JISU", userId)


que1 = int(input("What is 3 + 3 ? Enter Your answer here -> "))

if(que1 == 6):
    print("Correct Answer Score +1")
    
    
    que2 = input("What is the capital of India? Enter Your answer here -> ")
    
    if(que2 == "Delhi"):
        print("Correct Answer Score +1")
        
        
        que3 = int(input("What is 10 - 4 ? Enter Your answer here -> "))
        
        if(que3 == 6):
            print("Correct Answer Score +1")
            
            
            que4 = input("Which planet is known as Red Planet? Enter Your answer here -> ")
            
            if(que4 == "Mars"):
                print("Correct Answer Score +1")
                
                
                que5 = int(input("What is 5 * 2 ? Enter Your answer here -> "))
                
                if(que5 == 10):
                    print("Correct Answer Score +1")
                    print("Congratulations", userId, "You Won The Knock-Out Quiz 🎉")
                else:
                    print("Wrong Answer")
            else:
                print("Wrong Answer")
        else:
            print("Wrong Answer")
    else:
        print("Wrong Answer")
else:
    print("Wrong Answer")
# Out:
# Enter Your Name Here ->  amit
# Welcome to JISU amit
# What is 3 + 3 ? Enter Your answer here ->  3
# Wrong Answer
