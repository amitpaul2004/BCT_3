# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("titanic")

df.columns = df.columns.str.strip()

sorted_fare = df.sort_values("fare", ascending=False)

print(sorted_fare.head())
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 88   woman       False    C  Southampton   yes  False
# 27     man        True    C  Southampton    no  False

# %%
# Set 'who' column as index
df_indexed = df.set_index("who")

print(df_indexed.head())
# Out:
#        survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# who
# man           0       3    male  22.0      1      0   7.2500        S  Third
# woman         1       1  female  38.0      1      0  71.2833        C  First
# woman         1       3  female  26.0      0      0   7.9250        S  Third
# woman         1       1  female  35.0      1      0  53.1000        S  First
# man           0       3    male  35.0      0      0   8.0500        S  Third
#
#        adult_male deck  embark_town alive  alone
# who
# man          True  NaN  Southampton    no  False
# woman       False    C    Cherbourg   yes  False
# woman       False  NaN  Southampton   yes   True
# woman       False    C  Southampton   yes  False
# man          True  NaN  Southampton    no   True

# %%
# Access a row by index
print(df_indexed.loc["man"].head())
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# who
# man         0       3  male  22.0      1      0   7.2500        S  Third
# man         0       3  male  35.0      0      0   8.0500        S  Third
# man         0       3  male   NaN      0      0   8.4583        Q  Third
# man         0       1  male  54.0      0      0  51.8625        S  First
# man         0       3  male  20.0      0      0   8.0500        S  Third
#
#      adult_male deck  embark_town alive  alone
# who
# man        True  NaN  Southampton    no  False
# man        True  NaN  Southampton    no   True
# man        True  NaN   Queenstown    no   True
# man        True    E  Southampton    no   True
# man        True  NaN  Southampton    no   True

# %%
print(df_indexed.loc["child"].head())
# Out:
#        survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# who
# child         0       3    male   2.0      3      1  21.0750        S   Third
# child         1       2  female  14.0      1      0  30.0708        C  Second
# child         1       3  female   4.0      1      1  16.7000        S   Third
# child         0       3  female  14.0      0      0   7.8542        S   Third
# child         0       3    male   2.0      4      1  29.1250        Q   Third
#
#        adult_male deck  embark_town alive  alone
# who
# child       False  NaN  Southampton    no  False
# child       False  NaN    Cherbourg   yes  False
# child       False    G  Southampton   yes  False
# child       False  NaN  Southampton    no   True
# child       False  NaN   Queenstown    no  False

# %%
print(df_indexed.loc["woman"].head())
# Out:
#        survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# who
# woman         1       1  female  38.0      1      0  71.2833        C  First
# woman         1       3  female  26.0      0      0   7.9250        S  Third
# woman         1       1  female  35.0      1      0  53.1000        S  First
# woman         1       3  female  27.0      0      2  11.1333        S  Third
# woman         1       1  female  58.0      0      0  26.5500        S  First
#
#        adult_male deck  embark_town alive  alone
# who
# woman       False    C    Cherbourg   yes  False
# woman       False  NaN  Southampton   yes   True
# woman       False    C  Southampton   yes  False
# woman       False  NaN  Southampton   yes  False
# woman       False    C  Southampton   yes   True

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Histplot with category
sns.histplot(data=df, x="age", hue="who", bins=20)

plt.show()

# %%
# Histogram of passenger ages
sns.histplot(df['age'], bins=20, kde=True)

plt.title("Age Distribution of Titanic Passengers")
plt.xlabel("Age")
plt.ylabel("Count")

plt.show()

# %%
# Histogram of passenger ages
sns.histplot(df['age'], bins=100, kde=True)

plt.title("Age Distribution of Titanic Passengers")
plt.xlabel("Age")
plt.ylabel("Count")

plt.show()
