# %%
import pandas as pd

# Customers dataset
customers = pd.DataFrame({
    'customer_id': [1, 2, 3, 4],
    'name': ['Pravin', 'Kishore', 'Farhan', 'Rabi'],
    'region': ['Delhi', 'Madurai', 'Kolkata', 'Mumbai']
})
